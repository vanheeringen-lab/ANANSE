# %%
import sys 
import importlib
sys.path.append('../')

import pandas as pd

import dask.dataframe as dd

import ananse.interaction

importlib.reload(ananse.interaction)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-41a2de44acdf> in <module>
#       5 import pandas as pd
#       6
# ----> 7 import dask.dataframe as dd
#       8
#       9 import ananse.interaction
#
# ModuleNotFoundError: No module named 'dask'
